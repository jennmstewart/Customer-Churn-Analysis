# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

# Set the random seed for reproducibility
np.random.seed(42)

# Number of orders to generate
num_orders = 500

# Generate random data for each column
order_data = {
    'OrderID': range(1, num_orders + 1),
    'CustomerID': np.random.randint(1, 101, size=num_orders),  # 100 unique customers
    'ProductCategory': np.random.choice(['Electronics', 'Clothing', 'Furniture', 'Beauty', 'Sports'], size=num_orders),
    'OrderDate': [datetime.now() - timedelta(days=np.random.randint(1, 100)) for _ in range(num_orders)],
    'Quantity': np.random.randint(1, 10, size=num_orders),
    'UnitPrice': np.round(np.random.uniform(10, 500, size=num_orders), 2),
    'PaymentMethod': np.random.choice(['Credit Card', 'PayPal', 'Bank Transfer'], size=num_orders),
    'CustomerLocation': np.random.choice(['New York', 'Los Angeles', 'Chicago', 'Houston', 'Miami'], size=num_orders),
    'OrderStatus': np.random.choice(['Completed', 'Returned', 'Canceled'], size=num_orders)
}

# Create a DataFrame
df = pd.DataFrame(order_data)

# Calculate TotalPrice
df['TotalPrice'] = df['Quantity'] * df['UnitPrice']

# Generate random DeliveryDate and calculate DeliveryTime
df['DeliveryDate'] = df.apply(lambda x: x['OrderDate'] + timedelta(days=np.random.randint(1, 10)), axis=1)
df['DeliveryTime'] = (df['DeliveryDate'] - df['OrderDate']).dt.days

# Display the first few rows
df.head(10)
# Out:
#    OrderID  CustomerID ProductCategory                  OrderDate  Quantity  \
# 0        1          52          Beauty 2024-09-09 14:25:39.960327         7
# 1        2          93        Clothing 2024-07-05 14:25:39.960397         1
# 2        3          15       Furniture 2024-09-03 14:25:39.960416         8
# 3        4          72          Sports 2024-08-25 14:25:39.960428         3
# 4        5          61     Electronics 2024-08-11 14:25:39.960439         2
# 5        6          21          Sports 2024-08-14 14:25:39.960450         3
# 6        7          83          Beauty 2024-06-16 14:25:39.960461         5
# 7        8          87          Sports 2024-06-15 14:25:39.960471         8
# 8        9          75     Electronics 2024-07-31 14:25:39.960482         7
# 9       10          75          Beauty 2024-07-11 14:25:39.960492         7
#
#    UnitPrice  PaymentMethod CustomerLocation OrderStatus  TotalPrice  \
# 0     169.05         PayPal            Miami    Canceled     1183.35
# 1     189.57         PayPal         New York    Canceled      189.57
# 2     204.12         PayPal          Houston   Completed     1632.96
# 3     350.78  Bank Transfer      Los Angeles    Canceled     1052.34
# 4     200.39  Bank Transfer      Los Angeles   Completed      400.78
# 5     229.86         PayPal      Los Angeles    Canceled      689.58
# 6     126.40  Bank Transfer          Houston   Completed      632.00
# 7     192.89    Credit Card         New York   Completed     1543.12
# 8     121.36    Credit Card          Houston    Returned      849.52
# 9      45.87         PayPal      Los Angeles    Canceled      321.09
#
#                 DeliveryDate  DeliveryTime
# 0 2024-09-11 14:25:39.960327             2
# 1 2024-07-14 14:25:39.960397             9
# 2 2024-09-06 14:25:39.960416             3
# 3 2024-08-27 14:25:39.960428             2
# 4 2024-08-19 14:25:39.960439             8
# 5 2024-08-20 14:25:39.960450             6
# 6 2024-06-22 14:25:39.960461             6
# 7 2024-06-22 14:25:39.960471             7
# 8 2024-08-07 14:25:39.960482             7
# 9 2024-07-17 14:25:39.960492             6

# %%
sales_by_category = df.groupby('ProductCategory')['TotalPrice'].sum()
sales_by_category.plot(kind='bar', title='Total Sales by Product Category', color='skyblue')
plt.xlabel('Product Category')
plt.ylabel('Total Sales')
plt.show()

# %%
avg_delivery_time = df.groupby('CustomerLocation')['DeliveryTime'].mean()
avg_delivery_time.plot(kind='bar', title='Average Delivery Time by Location', color='lightgreen')
plt.xlabel('Customer Location')
plt.ylabel('Average Delivery Time (Days)')
plt.show()

# %%
payment_method_counts = df['PaymentMethod'].value_counts()
payment_method_counts.plot(kind='pie', autopct='%1.1f%%', title='Payment Method Distribution')
plt.ylabel('')
plt.show()

# %%
status_counts = df['OrderStatus'].value_counts()
status_counts.plot(kind='bar', title='Order Status Breakdown', color='coral')
plt.xlabel('Order Status')
plt.ylabel('Number of Orders')
plt.show()
